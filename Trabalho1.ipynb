# %% [markdown]
# # Trabalho 1 - Aprendizado de Maquina 2023/1 #
# Carlos Pereira de Castro Neto
#
# Vivian Ferreira Margarido
#
# Luan Dias Rodrigues
#
# Filipe Gabriel Soares Pereira Rodrigues

# %% [markdown]
# ## Estudo do Conjunto de Dados ##

# %% [markdown]
# ### Cojunto de dados de diagnóstico de câncer de mama em Wisconsin ###
# Classificação da Biópsia de Massa Mamária: Tumores Malignos vs Tumores Benignos
#
# Recursos de biópsia para classificação de 569 massas mamárias malignas (câncer) e benignas (não câncer).
#
# As características foram extraídas computacionalmente de imagens digitais de lâminas de biópsia por aspiração com agulha fina. As características correspondem às propriedades dos núcleos celulares, como tamanho, forma e regularidade. A média, o erro padrão e o pior valor de cada um dos 10 parâmetros nucleares são relatados para um total de 30 atributos.
#
# Disponivel em https://www.kaggle.com/datasets/utkarshx27/breast-cancer-wisconsin-diagnostic-dataset

# %% [markdown]
# ### Detalhes dos atributos ###
#
# - **y** - Os resultados. Um fator com dois níveis que indica se uma massa é maligna ("M") ou benigna ("B").
#
# - **x** - Os preditores. Uma matriz com a média, erro padrão e pior valor de cada uma das 10 medições nucleares em cada lâmina, totalizando 30 características por biópsia:
#
# * **radius** -  Raio do núcleo (média das distâncias do centro aos pontos na periferia).
#
# - **texture** - Textura do núcleo (desvio padrão dos valores em escala de cinza).
#
# - **perimeter** - Perímetro do núcleo.
#
# - **area** - Área do núcleo.
#
# - **smoothness** - Suavidade do núcleo (variação local nos comprimentos dos raios).
#
# - **compactness** - Compacidade do núcleo (perímetro^2/área - 1).
#
# - **concavity** - Concavidade do núcleo (gravidade das porções côncavas do contorno).
#
# - **concave_pts** - Número de porções côncavas do contorno do núcleo.
#
# - **symmetry** - Simetria do núcleo.
#
# - **fractal_dim** - Dimensão fractal do núcleo (aproximação da "linha da costa" - 1).
#
# - **_mean** - média.
#
# - **_se** - Erro padrão.
#
# - **_worst** - Pior/maior valor.

# %% [markdown]
# ### Importando o conjunto de dados ###

# %%
#Importando os dados sem a coluna 0 (indice)
import pandas as pd
df = pd.read_csv("brca.csv", index_col=0)
display(df)
# Out:
#      x.radius_mean  x.texture_mean  x.perimeter_mean  x.area_mean
# 1           13.540           14.36             87.46        566.3  \
# 2           13.080           15.71             85.63        520.0
# 3            9.504           12.44             60.34        273.9
# 4           13.030           18.42             82.61        523.8
# 5            8.196           16.84             51.71        201.9
# ..             ...             ...               ...          ...
# 565         20.920           25.09            143.00       1347.0
# 566         21.560           22.39            142.00       1479.0
# 567         20.130           28.25            131.20       1261.0
# 568         16.600           28.08            108.30        858.1
# 569         20.600           29.33            140.10       1265.0
#
#      x.smoothness_mean  x.compactness_mean  x.concavity_mean
# 1              0.09779             0.08129           0.06664  \
# 2              0.10750             0.12700           0.04568
# 3              0.10240             0.06492           0.02956
# 4              0.08983             0.03766           0.02562
# 5              0.08600             0.05943           0.01588
# ..                 ...                 ...               ...
# 565            0.10990             0.22360           0.31740
# 566            0.11100             0.11590           0.24390
# 567            0.09780             0.10340           0.14400
# 568            0.08455             0.10230           0.09251
# 569            0.11780             0.27700           0.35140
#
#      x.concave_pts_mean  x.symmetry_mean  x.fractal_dim_mean  ...
# 1              0.047810           0.1885             0.05766  ...  \
# 2              0.031100           0.1967             0.06811  ...
# 3              0.020760           0.1815             0.06905  ...
# 4              0.029230           0.1467             0.05863  ...
# 5              0.005917           0.1769             0.06503  ...
# ..                  ...              ...                 ...  ...
# 565            0.147400           0.2149             0.06879  ...
# 566            0.138900           0.1726             0.05623  ...
# 567            0.097910           0.1752             0.05533  ...
# 568            0.053020           0.1590             0.05648  ...
# 569            0.152000           0.2397             0.07016  ...
#
#      x.texture_worst  x.perimeter_worst  x.area_worst  x.smoothness_worst
# 1              19.26              99.70         711.2             0.14400  \
# 2              20.49              96.09         630.5             0.13120
# 3              15.66              65.13         314.9             0.13240
# 4              22.81              84.46         545.9             0.09701
# 5              21.96              57.26         242.2             0.12970
# ..               ...                ...           ...                 ...
# 565            29.41             179.10        1819.0             0.14070
# 566            26.40             166.10        2027.0             0.14100
# 567            38.25             155.00        1731.0             0.11660
# 568            34.12             126.70        1124.0             0.11390
# 569            39.42             184.60        1821.0             0.16500
#
#      x.compactness_worst  x.concavity_worst  x.concave_pts_worst
# 1                0.17730            0.23900              0.12880  \
# 2                0.27760            0.18900              0.07283
# 3                0.11480            0.08867              0.06227
# 4                0.04619            0.04833              0.05013
# 5                0.13570            0.06880              0.02564
# ..                   ...                ...                  ...
# 565              0.41860            0.65990              0.25420
# 566              0.21130            0.41070              0.22160
# 567              0.19220            0.32150              0.16280
# 568              0.30940            0.34030              0.14180
# 569              0.86810            0.93870              0.26500
#
#      x.symmetry_worst  x.fractal_dim_worst  y
# 1              0.2977              0.07259  B
# 2              0.3184              0.08183  B
# 3              0.2450              0.07773  B
# 4              0.1987              0.06169  B
# 5              0.3105              0.07409  B
# ..                ...                  ... ..
# 565            0.2929              0.09873  M
# 566            0.2060              0.07115  M
# 567            0.2572              0.06637  M
# 568            0.2218              0.07820  M
# 569            0.4087              0.12400  M
#
# [569 rows x 31 columns]

# %% [markdown]
# ### Informacoes estatisticas do Pandas ###

# %%
df.describe()
# Out:
#        x.radius_mean  x.texture_mean  x.perimeter_mean  x.area_mean
# count     569.000000      569.000000        569.000000   569.000000  \
# mean       14.127292       19.289649         91.969033   654.889104
# std         3.524049        4.301036         24.298981   351.914129
# min         6.981000        9.710000         43.790000   143.500000
# 25%        11.700000       16.170000         75.170000   420.300000
# 50%        13.370000       18.840000         86.240000   551.100000
# 75%        15.780000       21.800000        104.100000   782.700000
# max        28.110000       39.280000        188.500000  2501.000000
#
#        x.smoothness_mean  x.compactness_mean  x.concavity_mean
# count         569.000000          569.000000        569.000000  \
# mean            0.096360            0.104341          0.088799
# std             0.014064            0.052813          0.079720
# min             0.052630            0.019380          0.000000
# 25%             0.086370            0.064920          0.029560
# 50%             0.095870            0.092630          0.061540
# 75%             0.105300            0.130400          0.130700
# max             0.163400            0.345400          0.426800
#
#        x.concave_pts_mean  x.symmetry_mean  x.fractal_dim_mean  ...
# count          569.000000       569.000000          569.000000  ...  \
# mean             0.048919         0.181162            0.062798  ...
# std              0.038803         0.027414            0.007060  ...
# min              0.000000         0.106000            0.049960  ...
# 25%              0.020310         0.161900            0.057700  ...
# 50%              0.033500         0.179200            0.061540  ...
# 75%              0.074000         0.195700            0.066120  ...
# max              0.201200         0.304000            0.097440  ...
#
#        x.radius_worst  x.texture_worst  x.perimeter_worst  x.area_worst
# count      569.000000       569.000000         569.000000    569.000000  \
# mean        16.269190        25.677223         107.261213    880.583128
# std          4.833242         6.146258          33.602542    569.356993
# min          7.930000        12.020000          50.410000    185.200000
# 25%         13.010000        21.080000          84.110000    515.300000
# 50%         14.970000        25.410000          97.660000    686.500000
# 75%         18.790000        29.720000         125.400000   1084.000000
# max         36.040000        49.540000         251.200000   4254.000000
#
#        x.smoothness_worst  x.compactness_worst  x.concavity_worst
# count          569.000000           569.000000         569.000000  \
# mean             0.132369             0.254265           0.272188
# std              0.022832             0.157336           0.208624
# min              0.071170             0.027290           0.000000
# 25%              0.116600             0.147200           0.114500
# 50%              0.131300             0.211900           0.226700
# 75%              0.146000             0.339100           0.382900
# max              0.222600             1.058000           1.252000
#
#        x.concave_pts_worst  x.symmetry_worst  x.fractal_dim_worst
# count           569.000000        569.000000           569.000000
# mean              0.114606          0.290076             0.083946
# std               0.065732          0.061867             0.018061
# min               0.000000          0.156500             0.055040
# 25%               0.064930          0.250400             0.071460
# 50%               0.099930          0.282200             0.080040
# 75%               0.161400          0.317900             0.092080
# max               0.291000          0.663800             0.207500
#
# [8 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 1 to 569
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   x.radius_mean        569 non-null    float64
#  1   x.texture_mean       569 non-null    float64
#  2   x.perimeter_mean     569 non-null    float64
#  3   x.area_mean          569 non-null    float64
#  4   x.smoothness_mean    569 non-null    float64
#  5   x.compactness_mean   569 non-null    float64
#  6   x.concavity_mean     569 non-null    float64
#  7   x.concave_pts_mean   569 non-null    float64
#  8   x.symmetry_mean      569 non-null    float64
#  9   x.fractal_dim_mean   569 non-null    float64
#  10  x.radius_se          569 non-null    float64
#  11  x.texture_se         569 non-null    float64
#  12  x.perimeter_se       569 non-null    float64
#  13  x.area_se            569 non-null    float64
#  14  x.smoothness_se      569 non-null    float64
#  15  x.compactness_se     569 non-null    float64
#  16  x.concavity_se       569 non-null    float64
#  17  x.concave_pts_se     569 non-null    float64
#  18  x.symmetry_se        569 non-null    float64
#  19  x.fractal_dim_se     569 non-null    float64
#  20  x.radius_worst       569 non-null    float64
#  21  x.texture_worst      569 non-null    float64
#  22  x.perimeter_worst    569 non-null    float64
#  23  x.area_worst         569 non-null    float64
#  24  x.smoothness_worst   569 non-null    float64
#  25  x.compactness_worst  569 non-null    float64
#  26  x.concavity_worst    569 non-null    float64
#  27  x.concave_pts_worst  569 non-null    float64
#  28  x.symmetry_worst     569 non-null    float64
#  29  x.fractal_dim_worst  569 non-null    float64
#  30  y                    569 non-null    object
# dtypes: float64(30), object(1)
# memory usage: 142.2+ KB

# %%
#df.corr()

# %% [markdown]
# ### Algumas outras analises ###

# %%
# Contagem de classes
print("Contagem de classes:")
print(df.value_counts("y"))

# Verifica duplicatas
print(f"Existem {df.duplicated().sum()} objetos (linhas) duplicadas")

# Verificar colunas com valores zero
colunas_zero = df.columns[df.eq(0).any()]

# Verificar linhas com valores zero para cada coluna
linhas_zero_por_coluna = {}
for coluna in colunas_zero:
    linhas_zero_por_coluna[coluna] = df.index[df[coluna] == 0].tolist()
    
# Imprimir resultados
for coluna, linhas_zero in linhas_zero_por_coluna.items():
    print(f"Coluna '{coluna}' possui valores zero nas linhas: {linhas_zero}")
# Out:
# Contagem de classes:
# y
# B    357
# M    212
# Name: count, dtype: int64
# Existem 0 objetos (linhas) duplicadas
# Coluna 'x.concavity_mean' possui valores zero nas linhas: [36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]
# Coluna 'x.concave_pts_mean' possui valores zero nas linhas: [36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]
# Coluna 'x.concavity_se' possui valores zero nas linhas: [36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]
# Coluna 'x.concave_pts_se' possui valores zero nas linhas: [36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]
# Coluna 'x.concavity_worst' possui valores zero nas linhas: [36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]
# Coluna 'x.concave_pts_worst' possui valores zero nas linhas: [36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]

# %% [markdown]
# ### Plotagens ###

# %% [markdown]
# #### Preparativos ####

# %%
import matplotlib.pyplot as plt

columns = df.columns.tolist()

# Separo os dados nas 3 visoes
attributes_col_mean = columns[0:10]
attributes_col_se = columns[10:20]
attributes_col_worst = columns[20:-1]
classe_col = columns[-1]

# Preparo os dados relativos a classe pra plotagem
cores = {'B': 'blue', 'M': 'red'}
rotulos = {'B': 'B = Benigno', 'M': 'M = Maligno'}
cores_plotagem = [cores[c] for c in df[classe_col]]
rotulos_legenda = [rotulos[c] for c in df[classe_col]]
legendas = list(set(rotulos_legenda))

# %% [markdown]
# #### Media, Erro, Pior caso ####

# %%
# Visao media x Classe

for tipo in [attributes_col_mean, attributes_col_se, attributes_col_worst]:
    type_to_save = tipo[0].split("_")[-1]
    for col in tipo:
        plt.figure(figsize=(6, 2))
        plt.scatter(df[col], df[classe_col], s=5, c=cores_plotagem)
        plt.xlabel(f"Atributo: {col}")
        plt.ylabel(f"Classe {classe_col}")
        plt.title(f"Classe {classe_col} em função do atributo {col}")
        plt.grid(True, color='gray', linestyle ='--')
        plt.legend(legendas, title='Legendas')
        name_to_save = col.replace(".", "_")

        path_img = f"imagens/trabalho_1/{type_to_save}_{name_to_save}_versus_{classe_col}.png"
        plt.savefig(path_img, dpi=300)
        plt.close()
    
    # Plotar as imagens em um grid
    from PIL import Image
    fig, axes = plt.subplots(2, 5, figsize=(26, 4))
    for i, col in enumerate(tipo):
        row = i // 5
        column = i % 5
        name_to_save = col.replace(".", "_")
        path_img = f"imagens/trabalho_1/{type_to_save}_{name_to_save}_versus_{classe_col}.png"
        img = Image.open(path_img)
        axes[row, column].imshow(img)
        axes[row, column].axis('off')
    tipo_name = col.split("_")[-1]
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    plt.savefig(f'imagens/trabalho_1/{type_to_save}_grid_versus_{classe_col}.png', dpi=800)
    plt.show()
    plt.close()

# %%
df['y'].value_counts().plot(kind='bar', color= ['red','green'])
print(df['y'].value_counts())
plt.show()
# Out:
# y
# B    357
# M    212
# Name: count, dtype: int64

# %%
df_radius = df[["x.radius_mean", "y"]]
df_radius
# Out:
#      x.radius_mean  y
# 1           13.540  B
# 2           13.080  B
# 3            9.504  B
# 4           13.030  B
# 5            8.196  B
# ..             ... ..
# 565         20.920  M
# 566         21.560  M
# 567         20.130  M
# 568         16.600  M
# 569         20.600  M
#
# [569 rows x 2 columns]

# %%
import seaborn as sns
sns.boxplot(data=df, x="y", y="x.radius_mean")
# Out:
# <Axes: xlabel='y', ylabel='x.radius_mean'>

# %%
df.columns
# Out:
# Index(['x.radius_mean', 'x.texture_mean', 'x.perimeter_mean', 'x.area_mean',
#        'x.smoothness_mean', 'x.compactness_mean', 'x.concavity_mean',
#        'x.concave_pts_mean', 'x.symmetry_mean', 'x.fractal_dim_mean',
#        'x.radius_se', 'x.texture_se', 'x.perimeter_se', 'x.area_se',
#        'x.smoothness_se', 'x.compactness_se', 'x.concavity_se',
#        'x.concave_pts_se', 'x.symmetry_se', 'x.fractal_dim_se',
#        'x.radius_worst', 'x.texture_worst', 'x.perimeter_worst',
#        'x.area_worst', 'x.smoothness_worst', 'x.compactness_worst',
#        'x.concavity_worst', 'x.concave_pts_worst', 'x.symmetry_worst',
#        'x.fractal_dim_worst', 'y'],
#       dtype='object')

# %%
df_x = df.drop("y",axis=1)
df_radius = df[["x.radius_mean", "x.texture_mean","x.perimeter_mean", 
                "x.area_mean", "x.smoothness_mean", "x.compactness_mean",
                "x.concavity_mean", "x.concave_pts_mean", "x.symmetry_mean", "x.fractal_dim_mean"]]
sns.heatmap(df_radius.corr())
# Out:
# <Axes: >

# %%
df["y_numerico"] = 1
df.loc[df["y"] == "B", "y_numerico"] = 0
df[["x.radius_mean", "x.texture_mean","x.perimeter_mean", 
                "x.area_mean", "x.smoothness_mean", "x.compactness_mean",
                "x.concavity_mean", "x.concave_pts_mean", "x.symmetry_mean", 
                "x.fractal_dim_mean", "y_numerico"]].corr()
# Out:
#                     x.radius_mean  x.texture_mean  x.perimeter_mean
# x.radius_mean            1.000000        0.323782          0.997855  \
# x.texture_mean           0.323782        1.000000          0.329533
# x.perimeter_mean         0.997855        0.329533          1.000000
# x.area_mean              0.987357        0.321086          0.986507
# x.smoothness_mean        0.170581       -0.023389          0.207278
# x.compactness_mean       0.506124        0.236702          0.556936
# x.concavity_mean         0.676764        0.302418          0.716136
# x.concave_pts_mean       0.822529        0.293464          0.850977
# x.symmetry_mean          0.147741        0.071401          0.183027
# x.fractal_dim_mean      -0.311631       -0.076437         -0.261477
# y_numerico               0.730029        0.415185          0.742636
#
#                     x.area_mean  x.smoothness_mean  x.compactness_mean
# x.radius_mean          0.987357           0.170581            0.506124  \
# x.texture_mean         0.321086          -0.023389            0.236702
# x.perimeter_mean       0.986507           0.207278            0.556936
# x.area_mean            1.000000           0.177028            0.498502
# x.smoothness_mean      0.177028           1.000000            0.659123
# x.compactness_mean     0.498502           0.659123            1.000000
# x.concavity_mean       0.685983           0.521984            0.883121
# x.concave_pts_mean     0.823269           0.553695            0.831135
# x.symmetry_mean        0.151293           0.557775            0.602641
# x.fractal_dim_mean    -0.283110           0.584792            0.565369
# y_numerico             0.708984           0.358560            0.596534
#
#                     x.concavity_mean  x.concave_pts_mean  x.symmetry_mean
# x.radius_mean               0.676764            0.822529         0.147741  \
# x.texture_mean              0.302418            0.293464         0.071401
# x.perimeter_mean            0.716136            0.850977         0.183027
# x.area_mean                 0.685983            0.823269         0.151293
# x.smoothness_mean           0.521984            0.553695         0.557775
# x.compactness_mean          0.883121            0.831135         0.602641
# x.concavity_mean            1.000000            0.921391         0.500667
# x.concave_pts_mean          0.921391            1.000000         0.462497
# x.symmetry_mean             0.500667            0.462497         1.000000
# x.fractal_dim_mean          0.336783            0.166917         0.479921
# y_numerico                  0.696360            0.776614         0.330499
#
#                     x.fractal_dim_mean  y_numerico
# x.radius_mean                -0.311631    0.730029
# x.texture_mean               -0.076437    0.415185
# x.perimeter_mean             -0.261477    0.742636
# x.area_mean                  -0.283110    0.708984
# x.smoothness_mean             0.584792    0.358560
# x.compactness_mean            0.565369    0.596534
# x.concavity_mean              0.336783    0.696360
# x.concave_pts_mean            0.166917    0.776614
# x.symmetry_mean               0.479921    0.330499
# x.fractal_dim_mean            1.000000   -0.012838
# y_numerico                   -0.012838    1.000000

# %%
df.iloc[[36, 60, 84, 85, 95, 167, 221, 285, 333, 345, 352, 356, 357]]["y"]
# Out:
# 37     B
# 61     B
# 85     B
# 86     B
# 96     B
# 168    B
# 222    B
# 286    B
# 334    B
# 346    B
# 353    B
# 357    B
# 358    M
# Name: y, dtype: object

# %%
from sklearn import preprocessing
colunas = ["x.radius_mean", "x.texture_mean","x.perimeter_mean", 
                "x.area_mean", "x.smoothness_mean", "x.compactness_mean",
                "x.concavity_mean", "x.concave_pts_mean", "x.symmetry_mean", 
                "x.fractal_dim_mean", "y_numerico"]
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform( df[colunas])
df_normalize = pd.DataFrame(x_scaled, columns=colunas)
df_normalize[colunas].corr()
# Out:
#                     x.radius_mean  x.texture_mean  x.perimeter_mean
# x.radius_mean            1.000000        0.323782          0.997855  \
# x.texture_mean           0.323782        1.000000          0.329533
# x.perimeter_mean         0.997855        0.329533          1.000000
# x.area_mean              0.987357        0.321086          0.986507
# x.smoothness_mean        0.170581       -0.023389          0.207278
# x.compactness_mean       0.506124        0.236702          0.556936
# x.concavity_mean         0.676764        0.302418          0.716136
# x.concave_pts_mean       0.822529        0.293464          0.850977
# x.symmetry_mean          0.147741        0.071401          0.183027
# x.fractal_dim_mean      -0.311631       -0.076437         -0.261477
# y_numerico               0.730029        0.415185          0.742636
#
#                     x.area_mean  x.smoothness_mean  x.compactness_mean
# x.radius_mean          0.987357           0.170581            0.506124  \
# x.texture_mean         0.321086          -0.023389            0.236702
# x.perimeter_mean       0.986507           0.207278            0.556936
# x.area_mean            1.000000           0.177028            0.498502
# x.smoothness_mean      0.177028           1.000000            0.659123
# x.compactness_mean     0.498502           0.659123            1.000000
# x.concavity_mean       0.685983           0.521984            0.883121
# x.concave_pts_mean     0.823269           0.553695            0.831135
# x.symmetry_mean        0.151293           0.557775            0.602641
# x.fractal_dim_mean    -0.283110           0.584792            0.565369
# y_numerico             0.708984           0.358560            0.596534
#
#                     x.concavity_mean  x.concave_pts_mean  x.symmetry_mean
# x.radius_mean               0.676764            0.822529         0.147741  \
# x.texture_mean              0.302418            0.293464         0.071401
# x.perimeter_mean            0.716136            0.850977         0.183027
# x.area_mean                 0.685983            0.823269         0.151293
# x.smoothness_mean           0.521984            0.553695         0.557775
# x.compactness_mean          0.883121            0.831135         0.602641
# x.concavity_mean            1.000000            0.921391         0.500667
# x.concave_pts_mean          0.921391            1.000000         0.462497
# x.symmetry_mean             0.500667            0.462497         1.000000
# x.fractal_dim_mean          0.336783            0.166917         0.479921
# y_numerico                  0.696360            0.776614         0.330499
#
#                     x.fractal_dim_mean  y_numerico
# x.radius_mean                -0.311631    0.730029
# x.texture_mean               -0.076437    0.415185
# x.perimeter_mean             -0.261477    0.742636
# x.area_mean                  -0.283110    0.708984
# x.smoothness_mean             0.584792    0.358560
# x.compactness_mean            0.565369    0.596534
# x.concavity_mean              0.336783    0.696360
# x.concave_pts_mean            0.166917    0.776614
# x.symmetry_mean               0.479921    0.330499
# x.fractal_dim_mean            1.000000   -0.012838
# y_numerico                   -0.012838    1.000000

# %% [markdown]
# #### Selecionando atributos ####
#
# Observando os resultados dos atributos em função da classe, chegamos em algumas considerações:
#
# - Os dados de erro padrão (_se) não tem separação representativa para classes diferentes. Justificar: obviamente, como o erro padrão é algo relacionado com a medição e não com a classe de estudo, isso ja era esperado. Visto que a quantidade de objetos disponiveis para classificação é pequena, será feita uma rodada de classificação utilizando tais dados, porém se acredita que a retirada deles não influenciará na avaliação das classificações.
# - Comparando-se dados de media versus pior caso, observa-se uma grande semelhança entre os comportamentos. Para: radius, perimeter, area os piores dados aparentam ter uma melhor deinifição de classe. No restante não parece ser possível afirmar alguma diferença que se justifique a escolha entre um ou outro. Como uma medida conservadora, as classificações feitas serão repetidas para ambos os subconjuntos de forma que as avaliações dos classificações nos indiquem qual tipo de dado (média ou pior caso) seja melhor.
# - Tando na média, quanto no pior caso, podemos observar que alguns atributos tem uma melhor divisão entre as clases: radius, perimeter, área. O restante não aparentar ter uma divisão muito boa entre beligno e maligno. Afim de evitar erros, serão feitas classificações com todos os classificadores e depois comparados a esse conjunto visualmente melhor.
# - Neste subconjunto de atributos existe uma alta correlação, um caminho de estudo será combiná-los a outros atributos. *** Testar **

# %% [markdown]
# ## Classificacao ##

# %% [markdown]
# ### Pre-Processamento ###

# %% [markdown]
# #### Seleção de atributos ####

# %%
combine_atts = []
for att in attributes_col_mean[4:]:
    arr_att = attributes_col_mean[0:3]
    arr_att.append(att)
    combine_atts.append(arr_att)

sub_df = {
    "all" : df[columns[:-1]], # Todos os atributos
    "mean" : df[attributes_col_mean], # Todos os atributos de média
    "worst" : df[attributes_col_worst], # Todos os atritubos de pior caso
    "mean_rpa" : df[['x.radius_mean', 'x.perimeter_mean', 'x.area_mean']], # Os tres atributos escolhidos visualmente média
    "mean_rpaworst" : df[['x.radius_worst', 'x.perimeter_worst', 'x.area_worst']], # Os tres atributos escolhidos visualmente pior caso
    "mean_rpasmoot" : df[combine_atts[0]], # + smoothness_mean
    "mean_rpacompa" : df[combine_atts[1]], # + compactness_mean
    "mean_rpaconcav" : df[combine_atts[2]], # + concavity_mean
    "mean_rpaconcpt" : df[combine_atts[3]], # + concave_pts_mean
    "mean_rpasimme" : df[combine_atts[4]], # + symmetry_mean
    "mean_rpafract" : df[combine_atts[5]] # + fractal_dim_mean
}

# %% [markdown]
# ### Classificacao com KNN ###

# %%
#Impots 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

def plot_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.

    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix.
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.

    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names,
    )
    fig = plt.figure(figsize=figsize)
    sns.set(font_scale=1.4)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", annot_kws={"size": 16})
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return


results = []
for sub_key in sub_df:
    print(f"Classificando o conjunto com KNN: {sub_key}")
    # Separando entre atributos e classe
    X = sub_df[sub_key].iloc[:]
    y = df.iloc[:, -1]

    # Dividindo entre treino e teste
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

    # Tratamento dos dados
    # Normalizacao dos dados 
    minmax = MinMaxScaler()
    X_train_minmax = minmax.fit_transform(X_train)
    X_test_minmax = minmax.transform(X_test)

    # Classificacao com KNN
    knn_results = []
    # Vou variar o número do K viznhos
    for k in range(1,100):
        #Cria uma instância 
        KNN = KNeighborsClassifier(n_neighbors=k)

        #Ajusta a modelo aos dados de treino
        KNN = KNN.fit(X_train_minmax, y_train)

        # Predizendo os dados
        y_pred = KNN.predict(X_test_minmax)

        accuracy = accuracy_score(y_test, y_pred)*100

        knn_results.append((k, accuracy, KNN))
    
    result_ord = sorted(knn_results, key=lambda x: x[1])
    print(f"Melhor acurácia: {result_ord[0][1]:.4f}%, para k = {result_ord[0][0]}")
# Out:
# Classificando o conjunto com KNN: all
# Melhor acurácia: 93.0070%, para k = 92
# Classificando o conjunto com KNN: mean
# Melhor acurácia: 94.4056%, para k = 90
# Classificando o conjunto com KNN: worst
# Melhor acurácia: 95.1049%, para k = 32
# Classificando o conjunto com KNN: mean_rpa
# Melhor acurácia: 87.4126%, para k = 2
# Classificando o conjunto com KNN: mean_rpaworst
# Melhor acurácia: 89.5105%, para k = 1
# Classificando o conjunto com KNN: mean_rpasmoot
# Melhor acurácia: 91.6084%, para k = 1
# Classificando o conjunto com KNN: mean_rpacompa
# Melhor acurácia: 88.1119%, para k = 2
# Classificando o conjunto com KNN: mean_rpaconcav
# Melhor acurácia: 90.9091%, para k = 1
# Classificando o conjunto com KNN: mean_rpaconcpt
# Melhor acurácia: 93.7063%, para k = 1
# Classificando o conjunto com KNN: mean_rpasimme
# Melhor acurácia: 93.0070%, para k = 1
# Classificando o conjunto com KNN: mean_rpafract
# Melhor acurácia: 90.2098%, para k = 2

# %%
from sklearn.model_selection import train_test_split, cross_val_score
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

    # Tratamento dos dados
    # Normalizacao dos dados 
(max, i) = (0,0)
minmax = MinMaxScaler()
X_minmax = minmax.fit_transform(X)
X_test_minmax = minmax.transform(X_test) 
for k in range(1,200):
        #Cria uma instância 
    KNN = KNeighborsClassifier(n_neighbors=k)
        
    accuracy = cross_val_score(KNN, X_minmax, y, scoring="accuracy")
    #accuracy = accuracy.mean()
    #print(k, accuracy, accuracy.mean()) 
       #Ajusta a modelo aos dados de treino
        #KNN = KNN.fit(X_train_minmax, y_train)

        # Predizendo os dados
        #y_pred = KNN.predict(X_test_minmax)

        #accuracy = accuracy_score(y_test, y_pred)*100
    (max, i) = (max, i) if max > accuracy.mean() else (accuracy.mean(), k)
    #knn_results.append((k, accuracy.mean()))
    
    
#print(knn_results)
#result_ord = sorted(knn_results, key=lambda x: x[1])
#print(f"Melhor acurácia: {result_ord[0][1]:.4f}%, para k = {result_ord[0][0]}")
print(f"Melhor acurácia: {max:.4f}, para k = {i}")
# Out:
# 0.8611240490607048 1
# 0.8717435180872535 2
# 0.8857941313460642 3
# 0.8910883403198261 4
# 0.9015680794907623 5
# 0.9051234280391244 6
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# 0.912156497438286 7
# Melhor acurácia: 0.9122, para k = 7

# %% [markdown]
# ### Classificação com Árvores de decisão ###

# %%
from sklearn.tree import DecisionTreeClassifier

#sub_conjuntos_interesse = ['all', 'mean', 'worst', 'mean_rpa']
#subconjunto = {chave: dicionario[chave] for chave in chaves_desejadas}

for sub_key in sub_df:
    print(f"Classificando o conjunto com Árvores de decisão: {sub_key}")
    X = sub_df[sub_key].iloc[:]
    y = df.iloc[:, -1]
    
    # Dividindo entre treino e teste
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

    # Precisamos normalizar?

    # Como escolhemos esses parametros?? Variaremos eles??
    cls = DecisionTreeClassifier(random_state=1234, criterion='entropy',min_samples_leaf=10)
    cls.fit(X_train, y_train)
    y_pred = cls.predict(X_test)
    score_train = cls.score(X_train, y_train)*100
    score_test = cls.score(X_test, y_test)*100

    print(f"Training set score: {score_train:.4f}%, Test set score: {score_test:.4f}%")
# Out:
# Classificando o conjunto com Árvores de decisão: all
# Training set score: 95.7746%, Test set score: 96.5035%
# Classificando o conjunto com Árvores de decisão: mean
# Training set score: 95.0704%, Test set score: 94.4056%
# Classificando o conjunto com Árvores de decisão: worst
# Training set score: 96.2441%, Test set score: 95.8042%
# Classificando o conjunto com Árvores de decisão: mean_rpa
# Training set score: 91.3146%, Test set score: 88.8112%
# Classificando o conjunto com Árvores de decisão: mean_rpaworst
# Training set score: 93.1925%, Test set score: 90.9091%
# Classificando o conjunto com Árvores de decisão: mean_rpasmoot
# Training set score: 93.4272%, Test set score: 94.4056%
# Classificando o conjunto com Árvores de decisão: mean_rpacompa
# Training set score: 92.4883%, Test set score: 93.0070%
# Classificando o conjunto com Árvores de decisão: mean_rpaconcav
# Training set score: 92.0188%, Test set score: 92.3077%
# Classificando o conjunto com Árvores de decisão: mean_rpaconcpt
# Training set score: 94.8357%, Test set score: 94.4056%
# Classificando o conjunto com Árvores de decisão: mean_rpasimme
# Training set score: 92.9577%, Test set score: 93.7063%
# Classificando o conjunto com Árvores de decisão: mean_rpafract
# Training set score: 91.7840%, Test set score: 93.0070%

# %%
    # Classificação com Arvore de decisão
    # Revisar
    cls = DecisionTreeClassifier(random_state=1234, criterion='entropy',min_samples_leaf=10)
    cls.fit(X_train_minmax, y_train)
    y_pred = cls.predict(X_test_minmax)
    print('Training set score: {:.4f}'.format(cls.score(X_train, y_train)))
    print('Test set score: {:.4f}'.format(cls.score(X_test, y_test)))

    cf = confusion_matrix(y_test, y_pred)
    # print(plot_confusion_matrix(cf,class_names=["iris 1","iris 2","iris 3"]))

    # fig = plt.figure(figsize=(25,20))
    # _ = tree.plot_tree(cls,
    #                 feature_names=iris.feature_names,
    #                 class_names=iris.target_names,
    #                 filled=True)
    # fig.savefig("decistion_tree.png")
    print("Relatório de classificação: \n", classification_report(y_test, y_pred))
# Out:
# Training set score: 0.3662
# Test set score: 0.3916
# Relatório de classificação:
#                precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        87
#            1       0.98      0.84      0.90        56
#
#     accuracy                           0.93       143
#    macro avg       0.94      0.91      0.92       143
# weighted avg       0.93      0.93      0.93       143

# %%
cls = DecisionTreeClassifier(random_state=1234, criterion='entropy',min_samples_leaf=10)
accuracy = cross_val_score(KNN, X, y, scoring="accuracy")
print(accuracy, accuracy.mean())
# Out:
# [0.84210526 0.85087719 0.89473684 0.94736842 0.90265487] 0.8875485173109764

# %%
# Tratamento dos dados
# Normalizacao dos dados
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Padronizacao
# Transforma os dados de forma que a média seja 0 e o desvio padrão seja 1.
# Preserva a forma da distribuição original dos dados.
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# Normalizacao
# Transforma os dados de forma que eles sejam ajustados em uma faixa específica, geralmente entre 0 e 1.
# Os valores normalizados estarão na escala relativa aos valores mínimos e máximos originais.
# Preserva a ordem relativa dos dados.
minmax = MinMaxScaler()
X_train_minmax = minmax.fit_transform(X_train)
X_test_minmax = minmax.transform(X_test)

# %%
# Classificacao com KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

knn_saves = {}
accuracy = 0.0
max_ac = 0.0
for k in range(1,100):
    #Cria uma instância 
    KNN = KNeighborsClassifier(n_neighbors=k)

    #Ajusta a modelo aos dados de treino
    KNN = KNN.fit(X_train_minmax, y_train)    
    y_pred = KNN.predict(X_test_minmax)
    old_ac = accuracy
    accuracy = accuracy_score(y_test, y_pred)*100
    if round(old_ac, 2) != round(accuracy, 2):    
        print(f"KNeighborsClassifier, k = {k}, Acurácia: {accuracy:.3f}%")
    if accuracy > max_ac:
        max_ac = accuracy
        k_max = k
        y_pred_max = y_pred
print(f"KNeighborsClassifier, k = {k_max}, Acurácia maxima foi: {max_ac:.3f}%")
confusion_matrix = confusion_matrix(y_test, y_pred_max)
print(confusion_matrix)
# Out:
# KNeighborsClassifier, k = 1, Acurácia: 90.909%
# KNeighborsClassifier, k = 2, Acurácia: 90.210%
# KNeighborsClassifier, k = 3, Acurácia: 91.608%
# KNeighborsClassifier, k = 5, Acurácia: 93.007%
# KNeighborsClassifier, k = 6, Acurácia: 93.706%
# KNeighborsClassifier, k = 8, Acurácia: 93.007%
# KNeighborsClassifier, k = 9, Acurácia: 94.406%
# KNeighborsClassifier, k = 13, Acurácia: 95.105%
# KNeighborsClassifier, k = 14, Acurácia: 94.406%
# KNeighborsClassifier, k = 16, Acurácia: 93.706%
# KNeighborsClassifier, k = 17, Acurácia: 94.406%
# KNeighborsClassifier, k = 20, Acurácia: 93.706%
# KNeighborsClassifier, k = 21, Acurácia: 94.406%
# KNeighborsClassifier, k = 22, Acurácia: 93.706%
# KNeighborsClassifier, k = 23, Acurácia: 94.406%
# KNeighborsClassifier, k = 24, Acurácia: 93.706%
# KNeighborsClassifier, k = 25, Acurácia: 94.406%
# KNeighborsClassifier, k = 26, Acurácia: 93.706%
# KNeighborsClassifier, k = 28, Acurácia: 93.007%
# KNeighborsClassifier, k = 29, Acurácia: 93.706%
# KNeighborsClassifier, k = 30, Acurácia: 93.007%
# KNeighborsClassifier, k = 31, Acurácia: 93.706%
# KNeighborsClassifier, k = 33, Acurácia: 94.406%
# KNeighborsClassifier, k = 34, Acurácia: 93.706%
# KNeighborsClassifier, k = 35, Acurácia: 94.406%
# KNeighborsClassifier, k = 36, Acurácia: 93.706%
# KNeighborsClassifier, k = 41, Acurácia: 95.804%
# KNeighborsClassifier, k = 42, Acurácia: 94.406%
# KNeighborsClassifier, k = 43, Acurácia: 95.105%
# KNeighborsClassifier, k = 44, Acurácia: 94.406%
# KNeighborsClassifier, k = 48, Acurácia: 93.706%
# KNeighborsClassifier, k = 49, Acurácia: 95.105%
# KNeighborsClassifier, k = 50, Acurácia: 94.406%
# KNeighborsClassifier, k = 52, Acurácia: 93.007%
# KNeighborsClassifier, k = 56, Acurácia: 92.308%
# KNeighborsClassifier, k = 57, Acurácia: 93.706%
# KNeighborsClassifier, k = 58, Acurácia: 93.007%
# KNeighborsClassifier, k = 59, Acurácia: 93.706%
# KNeighborsClassifier, k = 60, Acurácia: 92.308%
# KNeighborsClassifier, k = 61, Acurácia: 93.007%
# KNeighborsClassifier, k = 62, Acurácia: 91.608%
# KNeighborsClassifier, k = 63, Acurácia: 92.308%
# KNeighborsClassifier, k = 65, Acurácia: 91.608%
# KNeighborsClassifier, k = 67, Acurácia: 90.909%
# KNeighborsClassifier, k = 68, Acurácia: 91.608%
# KNeighborsClassifier, k = 69, Acurácia: 92.308%
# KNeighborsClassifier, k = 70, Acurácia: 91.608%
# KNeighborsClassifier, k = 71, Acurácia: 92.308%
# KNeighborsClassifier, k = 72, Acurácia: 91.608%
# KNeighborsClassifier, k = 81, Acurácia: 92.308%
# KNeighborsClassifier, k = 86, Acurácia: 91.608%
# KNeighborsClassifier, k = 92, Acurácia: 90.909%
# KNeighborsClassifier, k = 93, Acurácia: 91.608%
# KNeighborsClassifier, k = 96, Acurácia: 90.909%
# KNeighborsClassifier, k = 97, Acurácia: 91.608%
# KNeighborsClassifier, k = 98, Acurácia: 90.909%
# KNeighborsClassifier, k = 41, Acurácia maxima foi: 95.804%
# [[86  1]
#  [ 5 51]]

# %% [markdown]
# ### Classificacao com Regressao Logistica ###

# %%
# Classificacao com Regressao Logistica
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

logreg = LogisticRegression()
logreg.fit(X_train_minmax, y_train)

y_pred = logreg.predict(X_test_minmax)
accuracy = accuracy_score(y_test, y_pred)*100
print(f"LogisticRegression, Acurácia: {accuracy:.3f}%")

# Coeficientes (pesos)
coefficients = logreg.coef_
print(coefficients)

# Interceptação (viés)
intercept = logreg.intercept_
print(intercept)

confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# LogisticRegression, Acurácia: 97.203%
# [[ 1.65191363  1.4638372   1.62298474  1.41363144  0.56381112  0.28177295
#    1.28684419  1.96972405  0.26108668 -0.88266508  0.97638362 -0.18337907
#    0.72480041  0.68082742 -0.1790059  -0.74299752 -0.28828931  0.03730417
#   -0.2126357  -0.6108632   2.23934221  2.1556573   2.0276012   1.63603535
#    1.66639872  0.74062681  1.2379186   2.51591578  1.15081358  0.37549409]]
# [-8.27208647]
# [[87  0]
#  [ 4 52]]
